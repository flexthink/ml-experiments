# %% [markdown]
# # Basic Neural Robot Control - Training
#
# The objective of this experiment is to control the Cozmo robot using a neural network, attempting to replicate the behaviour patterns of a human controller.
#
# The approach used here is to use an LSTM RNN to predict the next action taken by the human from a fixed-length sequence of environment observations and prevously taken actions.
#
# In the current version, the following environment observations are taken into consideration:
# - The inferred position and angle of the robot (as provided by the Cozmo API)
# - The positions of each of the three light-cubes (if visible)
#
# The following actions are available:
# - Drive forward
# - Drive back
# - Turn left
# - Turn right
# - Lift up
# - Lift down
# - Head up
# - Head down
#
# The vector of observations is concatenated together with the vector of actions (represented as 1.0 / 0.0) to produce a single time-step to the RNN. The output of the network is the actions.
#
# The training approach involves using a sliding window over the training data set with two hyperparameters:
# - *horizon* - the number of steps (recording snapshots) to be examined by the network in a single step
# - *step size*  - (usually, a smaller value) the number of observations the sliding window is moved by for each training example
#
# The network will attempt to predict the actions in the first snapshot outside of the sliding window.
#
# Directions for future experiments (TODO):
# - Adding the rotation quaternions of each cube
# - Adding a scene embedding produced from the raw camera footage
# - Adding metrics and a test set
# - Adding dropout

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from glob import glob
K = tf.keras
L = K.layers
from ipywidgets import interact_manual
import ipywidgets as widgets
import matplotlib.pyplot as plt

# %%
def read_recordings(pattern):
    return pd.concat(pd.read_hdf(file_name, 'robot') for file_name in glob(pattern)).reset_index(drop=True)

# %%
control_data = read_recordings('robot-*.h5')
control_data
# Out:
#       robot_position_x  robot_position_y  robot_angle cube_1_visible  \
# 0            43.889851        -18.560421    -0.440358          False
# 1            43.889851        -18.560421    -0.440384          False
# 2            43.889851        -18.560421    -0.440375          False
# 3            43.889851        -18.560421    -0.440375          False
# 4            43.889851        -18.560421    -0.440348          False
# 5            43.889851        -18.560421    -0.440348          False
# 6            43.889851        -18.560421    -0.440311          False
# 7            43.889851        -18.560421    -0.440288          False
# 8            43.889851        -18.560421    -0.440288          False
# 9            43.889851        -18.560421    -0.440298          False
# 10           43.889851        -18.560421    -0.440312          False
# 11           43.889851        -18.560421    -0.440326          False
# 12           43.889851        -18.560421    -0.440311          False
# 13           43.889851        -18.560421    -0.440313          False
# 14           43.999924        -18.610910    -0.440001          False
# 15           45.261887        -19.192879    -0.439109          False
# 16           47.812263        -20.380859    -0.439021          False
# 17           52.774025        -22.648302    -0.436453          False
# 18           56.085724        -24.158449    -0.434665          False
# 19           59.555389        -25.743294    -0.432075          False
# 20           63.153435        -27.376122    -0.430191          False
# 21           66.814293        -29.003021    -0.426248          False
# 22           70.722145        -30.727983    -0.422149          False
# 23           74.671448        -32.472382    -0.418484          False
# 24           76.635246        -33.317287    -0.416706          False
# 25           82.732826        -35.943043    -0.412958          False
# 26           92.833618        -41.274784    -0.448189          False
# 27           92.833618        -41.274784    -0.448189          False
# 28          102.750977        -46.692612    -0.477965          False
# 29          107.016159        -48.938583    -0.480103          False
# ...                ...               ...          ...            ...
# 7466       -200.030487       -291.600677     0.019290          False
# 7467       -200.030487       -291.600677     0.019257          False
# 7468       -200.030487       -291.600677     0.019257          False
# 7469       -200.030487       -291.600677     0.019183          False
# 7470       -200.030487       -291.600677     0.019220          False
# 7471       -200.030487       -291.600677     0.019318          False
# 7472       -200.030487       -291.600677     0.019348          False
# 7473       -200.030487       -291.600677     0.019341          False
# 7474       -200.030487       -291.600677     0.019334          False
# 7475       -200.030487       -291.600677     0.019334          False
# 7476       -200.030487       -291.600677     0.019423          False
# 7477       -200.030487       -291.600677     0.019485          False
# 7478       -200.030487       -291.600677     0.019501          False
# 7479       -200.030487       -291.600677     0.019526          False
# 7480       -200.030487       -291.600677     0.019584          False
# 7481       -200.030487       -291.600677     0.019554          False
# 7482       -200.030487       -291.600677     0.019519          False
# 7483       -200.030487       -291.600677     0.019519          False
# 7484       -200.030487       -291.600677     0.019522          False
# 7485       -200.030487       -291.600677     0.019526          False
# 7486       -200.030487       -291.600677     0.019557          False
# 7487       -200.030487       -291.600677     0.019542          False
# 7488       -200.030487       -291.600677     0.019484          False
# 7489       -200.030487       -291.600677     0.019529          False
# 7490       -200.030487       -291.600677     0.019546          False
# 7491       -200.030487       -291.600677     0.019515          False
# 7492       -200.030487       -291.600677     0.019518          False
# 7493       -200.030487       -291.600677     0.019486          False
# 7494       -200.030487       -291.600677     0.019445          False
# 7495       -200.030487       -291.600677     0.019492          False
#
#       cube_1_x  cube_1_y cube_2_visible  cube_2_x  cube_2_y cube_3_visible  \
# 0          0.0       0.0          False       0.0       0.0          False
# 1          0.0       0.0          False       0.0       0.0          False
# 2          0.0       0.0          False       0.0       0.0          False
# 3          0.0       0.0          False       0.0       0.0          False
# 4          0.0       0.0          False       0.0       0.0          False
# 5          0.0       0.0          False       0.0       0.0          False
# 6          0.0       0.0          False       0.0       0.0          False
# 7          0.0       0.0          False       0.0       0.0          False
# 8          0.0       0.0          False       0.0       0.0          False
# 9          0.0       0.0          False       0.0       0.0          False
# 10         0.0       0.0          False       0.0       0.0          False
# 11         0.0       0.0          False       0.0       0.0          False
# 12         0.0       0.0          False       0.0       0.0          False
# 13         0.0       0.0          False       0.0       0.0          False
# 14         0.0       0.0          False       0.0       0.0          False
# 15         0.0       0.0          False       0.0       0.0          False
# 16         0.0       0.0          False       0.0       0.0          False
# 17         0.0       0.0          False       0.0       0.0          False
# 18         0.0       0.0          False       0.0       0.0          False
# 19         0.0       0.0          False       0.0       0.0          False
# 20         0.0       0.0          False       0.0       0.0          False
# 21         0.0       0.0          False       0.0       0.0          False
# 22         0.0       0.0          False       0.0       0.0          False
# 23         0.0       0.0          False       0.0       0.0          False
# 24         0.0       0.0          False       0.0       0.0          False
# 25         0.0       0.0          False       0.0       0.0          False
# 26         0.0       0.0          False       0.0       0.0          False
# 27         0.0       0.0          False       0.0       0.0          False
# 28         0.0       0.0          False       0.0       0.0          False
# 29         0.0       0.0          False       0.0       0.0          False
# ...        ...       ...            ...       ...       ...            ...
# 7466       0.0       0.0          False       0.0       0.0          False
# 7467       0.0       0.0          False       0.0       0.0          False
# 7468       0.0       0.0          False       0.0       0.0          False
# 7469       0.0       0.0          False       0.0       0.0          False
# 7470       0.0       0.0          False       0.0       0.0          False
# 7471       0.0       0.0          False       0.0       0.0          False
# 7472       0.0       0.0          False       0.0       0.0          False
# 7473       0.0       0.0          False       0.0       0.0          False
# 7474       0.0       0.0          False       0.0       0.0          False
# 7475       0.0       0.0          False       0.0       0.0          False
# 7476       0.0       0.0          False       0.0       0.0          False
# 7477       0.0       0.0          False       0.0       0.0          False
# 7478       0.0       0.0          False       0.0       0.0          False
# 7479       0.0       0.0          False       0.0       0.0          False
# 7480       0.0       0.0          False       0.0       0.0          False
# 7481       0.0       0.0          False       0.0       0.0          False
# 7482       0.0       0.0          False       0.0       0.0          False
# 7483       0.0       0.0          False       0.0       0.0          False
# 7484       0.0       0.0          False       0.0       0.0          False
# 7485       0.0       0.0          False       0.0       0.0          False
# 7486       0.0       0.0          False       0.0       0.0          False
# 7487       0.0       0.0          False       0.0       0.0          False
# 7488       0.0       0.0          False       0.0       0.0          False
# 7489       0.0       0.0          False       0.0       0.0          False
# 7490       0.0       0.0          False       0.0       0.0          False
# 7491       0.0       0.0          False       0.0       0.0          False
# 7492       0.0       0.0          False       0.0       0.0          False
# 7493       0.0       0.0          False       0.0       0.0          False
# 7494       0.0       0.0          False       0.0       0.0          False
# 7495       0.0       0.0          False       0.0       0.0          False
#
#       cube_3_x  cube_3_y action_drive_forwards action_drive_back  \
# 0          0.0       0.0                 False                 0
# 1          0.0       0.0                 False                 0
# 2          0.0       0.0                 False                 0
# 3          0.0       0.0                 False                 0
# 4          0.0       0.0                 False                 0
# 5          0.0       0.0                 False                 0
# 6          0.0       0.0                 False                 0
# 7          0.0       0.0                  True                 0
# 8          0.0       0.0                  True                 0
# 9          0.0       0.0                  True                 0
# 10         0.0       0.0                  True                 0
# 11         0.0       0.0                  True                 0
# 12         0.0       0.0                  True                 0
# 13         0.0       0.0                  True                 0
# 14         0.0       0.0                  True                 0
# 15         0.0       0.0                  True                 0
# 16         0.0       0.0                  True                 0
# 17         0.0       0.0                  True                 0
# 18         0.0       0.0                  True                 0
# 19         0.0       0.0                  True                 0
# 20         0.0       0.0                  True                 0
# 21         0.0       0.0                  True                 0
# 22         0.0       0.0                  True                 0
# 23         0.0       0.0                  True                 0
# 24         0.0       0.0                  True                 0
# 25         0.0       0.0                  True                 0
# 26         0.0       0.0                  True                 0
# 27         0.0       0.0                  True                 0
# 28         0.0       0.0                  True                 0
# 29         0.0       0.0                  True                 0
# ...        ...       ...                   ...               ...
# 7466       0.0       0.0                 False             False
# 7467       0.0       0.0                 False             False
# 7468       0.0       0.0                 False             False
# 7469       0.0       0.0                 False             False
# 7470       0.0       0.0                 False             False
# 7471       0.0       0.0                 False             False
# 7472       0.0       0.0                 False             False
# 7473       0.0       0.0                 False             False
# 7474       0.0       0.0                 False             False
# 7475       0.0       0.0                 False             False
# 7476       0.0       0.0                 False             False
# 7477       0.0       0.0                 False             False
# 7478       0.0       0.0                 False             False
# 7479       0.0       0.0                 False             False
# 7480       0.0       0.0                 False             False
# 7481       0.0       0.0                 False             False
# 7482       0.0       0.0                 False             False
# 7483       0.0       0.0                 False             False
# 7484       0.0       0.0                 False             False
# 7485       0.0       0.0                 False             False
# 7486       0.0       0.0                 False             False
# 7487       0.0       0.0                 False             False
# 7488       0.0       0.0                 False             False
# 7489       0.0       0.0                 False             False
# 7490       0.0       0.0                 False             False
# 7491       0.0       0.0                 False             False
# 7492       0.0       0.0                 False             False
# 7493       0.0       0.0                 False             False
# 7494       0.0       0.0                 False             False
# 7495       0.0       0.0                 False             False
#
#      action_turn_left action_turn_right action_lift_up action_lift_down  \
# 0                   0             False              0            False
# 1                   0             False              0            False
# 2                   0             False              0            False
# 3                   0             False              0            False
# 4                   0             False              0            False
# 5                   0             False              0            False
# 6                   0             False              0            False
# 7                   0             False              0            False
# 8                   0             False              0            False
# 9                   0             False              0            False
# 10                  0             False              0            False
# 11                  0             False              0            False
# 12                  0             False              0            False
# 13                  0             False              0            False
# 14                  0             False              0            False
# 15                  0             False              0            False
# 16                  0             False              0            False
# 17                  0             False              0            False
# 18                  0             False              0            False
# 19                  0             False              0            False
# 20                  0             False              0            False
# 21                  0             False              0            False
# 22                  0              True              0            False
# 23                  0              True              0            False
# 24                  0              True              0            False
# 25                  0             False              0            False
# 26                  0             False              0            False
# 27                  0             False              0            False
# 28                  0             False              0            False
# 29                  0             False              0            False
# ...               ...               ...            ...              ...
# 7466            False             False          False            False
# 7467            False             False          False            False
# 7468            False             False          False            False
# 7469            False             False          False            False
# 7470            False             False          False            False
# 7471            False             False          False            False
# 7472            False             False          False            False
# 7473            False             False          False            False
# 7474            False             False          False            False
# 7475            False             False          False            False
# 7476            False             False          False            False
# 7477            False             False          False            False
# 7478            False             False          False            False
# 7479            False             False          False            False
# 7480            False             False          False            False
# 7481            False             False          False            False
# 7482            False             False          False            False
# 7483            False             False          False            False
# 7484            False             False          False            False
# 7485            False             False          False            False
# 7486            False             False          False            False
# 7487            False             False          False            False
# 7488            False             False          False            False
# 7489            False             False          False            False
# 7490            False             False          False            False
# 7491            False             False          False            False
# 7492            False             False          False            False
# 7493            False             False          False            False
# 7494            False             False          False            False
# 7495            False             False          False            False
#
#      action_head_up action_head_down
# 0                 0            False
# 1                 0            False
# 2                 0            False
# 3                 0            False
# 4                 0            False
# 5                 0            False
# 6                 0            False
# 7                 0            False
# 8                 0            False
# 9                 0            False
# 10                0            False
# 11                0            False
# 12                0            False
# 13                0            False
# 14                0            False
# 15                0            False
# 16                0            False
# 17                0            False
# 18                0            False
# 19                0            False
# 20                0            False
# 21                0            False
# 22                0            False
# 23                0            False
# 24                0            False
# 25                0            False
# 26                0            False
# 27                0            False
# 28                0            False
# 29                0            False
# ...             ...              ...
# 7466          False            False
# 7467          False            False
# 7468          False            False
# 7469          False            False
# 7470          False            False
# 7471          False            False
# 7472          False            False
# 7473          False            False
# 7474          False            False
# 7475          False            False
# 7476          False            False
# 7477          False            False
# 7478          False            False
# 7479          False            False
# 7480          False            False
# 7481          False            False
# 7482          False            False
# 7483          False            False
# 7484          False            False
# 7485          False            False
# 7486          False            False
# 7487          False            False
# 7488          False            False
# 7489          False            False
# 7490          False            False
# 7491          False            False
# 7492          False            False
# 7493          False            False
# 7494          False            False
# 7495          False            False
#
# [7496 rows x 20 columns]

# %%
control_data = control_data.astype(np.float64)

# %%
def get_actions(data):
    return [col for col in data.columns if col.startswith('action_')]

# %%
def get_model(data_sample, horizon):
    control_vector_size = len(data_sample.columns)
    actions = get_actions(data_sample)
    model = K.Sequential()
    model.add(L.LSTM(32, return_sequences=True, stateful=False,
                     input_shape=(horizon, control_vector_size)))
    model.add(L.LSTM(32, return_sequences=True, stateful=False))
    model.add(L.LSTM(32, return_sequences=False, stateful=False))
    model.add(L.Dense(len(actions), activation='hard_sigmoid'))
    return model

# %%
def get_control_sample(control_data_matrix, x, horizon):
    sample = control_data_matrix[x:x+horizon]
    sample = np.pad(
        sample, 
        pad_width=((0, (horizon - len(sample))), (0, 0)),
        mode='edge' if len(sample) else 'constant') 
    return sample

def get_batch(control_data_matrix, horizon, step_size, x, batch_size):
    batch_range = range(x, x+step_size*batch_size, step_size)
    batch_x = np.stack(
        get_control_sample(control_data_matrix, x1, horizon)
        for x1 in batch_range
    )
    batch_y = np.stack(
        np.squeeze(get_control_sample(control_data_matrix, x + horizon, 1)[:, -8:])
        for x1 in batch_range
    )
    return batch_x, batch_y

def get_data_generator(control_data, horizon, step_size, batch_size):
    control_data_matrix = control_data.astype(np.float64).as_matrix()
    return (
        get_batch(control_data_matrix, horizon, step_size, x, batch_size)
        for x in range(0, len(control_data), step_size*batch_size))

# %%
horizon = 32
step_size = 5
model = get_model(control_data, horizon=horizon)
actions = get_actions(control_data)
model.compile(loss='mean_squared_error', optimizer='rmsprop')
batch_size = 20

# %%
epochs = 10
for _ in range(epochs):
    generator = get_data_generator(control_data, horizon=horizon, step_size=step_size, batch_size=batch_size)
    model.fit_generator(generator, steps_per_epoch=len(control_data)/step_size/batch_size)
# Out:
# Epoch 1/1
# 75/74 [==============================] - 8s 110ms/step - loss: 0.0441
# Epoch 1/1
# 75/74 [==============================] - 8s 112ms/step - loss: 0.0411
# Epoch 1/1
# 75/74 [==============================] - 8s 108ms/step - loss: 0.0423
# Epoch 1/1
# 75/74 [==============================] - 8s 110ms/step - loss: 0.0421
# Epoch 1/1
# 75/74 [==============================] - 8s 109ms/step - loss: 0.0422
# Epoch 1/1
# 75/74 [==============================] - 9s 114ms/step - loss: 0.0410
# Epoch 1/1
# 75/74 [==============================] - 8s 113ms/step - loss: 0.0394
# Epoch 1/1
# 75/74 [==============================] - 8s 113ms/step - loss: 0.0393
# Epoch 1/1
# 75/74 [==============================] - 9s 119ms/step - loss: 0.0389
# Epoch 1/1
# 75/74 [==============================] - 9s 117ms/step - loss: 0.0379

# %%
# %matplotlib inline
min_robot_x, max_robot_x = control_data.robot_position_x.min(), control_data.robot_position_x.max()
min_robot_y, max_robot_y = control_data.robot_position_y.min(), control_data.robot_position_y.max()
arrow_length = 100
arrow_width = 2
padding = 20
actions = [column.replace('action_', '') for column in control_data.columns
           if column.startswith('action_')]
control_data_matrix = control_data.astype(np.float64).as_matrix()

@interact_manual(x=widgets.IntText(min=0, max=len(control_data), continuous_update=False))
def plot(x):
    plt.figure(figsize=(12, 8))
    sample = control_data.loc[x+horizon]
    prediction_sample = get_control_sample(control_data_matrix, x, horizon)
    predicted_actions = np.squeeze(model.predict(np.expand_dims(prediction_sample, axis=0)))
    plt.subplot(2, 1, 1)
    plt.xlim(min_robot_x - padding, max_robot_x + padding)
    plt.ylim(min_robot_y - padding, max_robot_y + padding)
    plt.plot(sample.robot_position_x, sample.robot_position_y, 'ro')
    plt.arrow(sample.robot_position_x, sample.robot_position_y, 
              arrow_length * np.cos(sample.robot_angle),
              arrow_length * np.sin(sample.robot_angle),
              width=arrow_width)
    plt.subplot(2, 1, 2)
    actions_range = range(len(actions))    
    plt.bar(actions_range, predicted_actions)
    plt.xticks(actions_range, actions)
    plt.xlim(-1, len(actions))
    plt.ylim(0, 1.0)
    for idx, action in enumerate(actions):
        if sample[f'action_{action}']:
            plt.plot(idx, predicted_actions[idx], 'ro')
    
    for cube_idx in range(1, 4):
        if sample[f'cube_{cube_idx}_visible']:
            plt.plot(sample[f'cube_{cube_idx}_x'], sample[f'cube_{cube_idx}_y'], 'b+')
# Out:
# interactive(children=(IntText(value=0, description='x'), Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widget-interact',))

# %%
model.save('basic_neural_control_lstm.h5')
